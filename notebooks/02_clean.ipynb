# %% [markdown]
# # 02_CLEAN — Traffy Fondue Data Preperation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv('../data_raw/bangkok_traffy_raw.csv', low_memory=False)

df.head()
# Out:
#      ticket_id                 type                      organization  \
# 0  2021-FYJTFP          {ความสะอาด}                        เขตบางซื่อ
# 1  2021-CGPMUN  {น้ำท่วม,ร้องเรียน}      เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2  2021-7XATFA              {สะพาน}                           เขตสาทร
# 3  2021-9U2NJT            {น้ำท่วม}    เขตบางซื่อ,ฝ่ายโยธา เขตบางซื่อ
# 4  2021-DVEWYM        {น้ำท่วม,ถนน}  เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
#
#                                              comment  \
# 0                                            ขยะเยอะ
# 1  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 3                                            น้ำท่วม
# 4  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
#
#                                                photo  \
# 0  https://storage.googleapis.com/traffy_public_b...
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# 3  https://storage.googleapis.com/traffy_public_b...
# 4  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 0                                                NaN  100.53084,13.81865
# 1  https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                NaN  100.52649,13.72060
# 3  https://storage.googleapis.com/traffy_public_b...  100.53099,13.81853
# 4                                                NaN  100.59165,13.82280
#
#                                              address subdistrict  district  \
# 0  12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...         NaN       NaN
# 1  189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2  191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 3  12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...         NaN       NaN
# 4  702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
#
#         province                      timestamp      state  star  \
# 0  กรุงเทพมหานคร  2021-09-03 12:51:09.453003+00  เสร็จสิ้น   NaN
# 1  กรุงเทพมหานคร  2021-09-19 14:56:08.924992+00  เสร็จสิ้น   4.0
# 2  กรุงเทพมหานคร  2021-09-26 05:03:52.594898+00  เสร็จสิ้น   NaN
# 3  กรุงเทพมหานคร  2021-10-14 10:45:27.713884+00  เสร็จสิ้น   NaN
# 4  กรุงเทพมหานคร  2021-12-09 12:29:08.408763+00  เสร็จสิ้น   5.0
#
#    count_reopen                  last_activity
# 0             0  2022-06-04 15:34:14.609206+00
# 1             0  2022-06-21 08:21:09.532782+00
# 2             0  2022-06-06 01:17:12.272904+00
# 3             0  2022-09-08 08:35:43.784519+00
# 4             0  2022-08-12 07:18:44.884945+00

# %% [markdown]
# # Standardize Missing Values

# %%
missing_tokens = ["", " ", "N/A", "n/a", "na", "null", "None", "-", "ไม่ระบุ", "{}"]
df = df.replace(missing_tokens, np.nan)
df.head(10)
# Out:
#      ticket_id                 type  \
# 0  2021-FYJTFP          {ความสะอาด}
# 1  2021-CGPMUN  {น้ำท่วม,ร้องเรียน}
# 2  2021-7XATFA              {สะพาน}
# 3  2021-9U2NJT            {น้ำท่วม}
# 4  2021-DVEWYM        {น้ำท่วม,ถนน}
# 5  2021-4D9Y98                  NaN
# 6  2021-7U9RED                  NaN
# 7  2021-8N9ZP8          {ความสะอาด}
# 8  2021-7K6QA3                  NaN
# 9  2021-8BTWZB        {ท่อระบายน้ำ}
#
#                                         organization  \
# 0                                         เขตบางซื่อ
# 1                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2                                            เขตสาทร
# 3                     เขตบางซื่อ,ฝ่ายโยธา เขตบางซื่อ
# 4                   เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 5           เขตลาดพร้าว,การไฟฟ้านครหลวง เขตนวลจันทร์
# 6                                           เขตดุสิต
# 7  เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ,ฝ่ายรักษาความสะ...
# 8                     เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ
# 9                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
#
#                                              comment  \
# 0                                            ขยะเยอะ
# 1  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2    สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 3                                            น้ำท่วม
# 4  ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 5                        หน้าปากซอย ลาดพร้าววังหิน26
# 6  ยังไม่มีหน่วยงานไหนมาดูแลครับ รถจะเชี่ยวหลายคน...
# 7                  คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 8  ระยะหลังๆ นี้ พบเจอรถสิบล้อขนดิน ใส่ยางบังโคลน...
# 9  ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
#
#                                                photo  \
# 0  https://storage.googleapis.com/traffy_public_b...
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# 3  https://storage.googleapis.com/traffy_public_b...
# 4  https://storage.googleapis.com/traffy_public_b...
# 5  https://storage.googleapis.com/traffy_public_b...
# 6  https://storage.googleapis.com/traffy_public_b...
# 7  https://storage.googleapis.com/traffy_public_b...
# 8  https://storage.googleapis.com/traffy_public_b...
# 9  https://storage.googleapis.com/traffy_public_b...
#
#                                          photo_after              coords  \
# 0                                                NaN  100.53084,13.81865
# 1  https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                NaN  100.52649,13.72060
# 3  https://storage.googleapis.com/traffy_public_b...  100.53099,13.81853
# 4                                                NaN  100.59165,13.82280
# 5  https://storage.googleapis.com/traffy_public_b...  100.59131,13.80910
# 6  https://storage.googleapis.com/traffy_public_b...  100.50848,13.77832
# 7  https://storage.googleapis.com/traffy_public_b...  100.64690,13.67083
# 8  https://storage.googleapis.com/traffy_public_b...  100.65617,13.72812
# 9  https://storage.googleapis.com/traffy_public_b...  100.65440,13.68158
#
#                                              address subdistrict  district  \
# 0  12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...         NaN       NaN
# 1  189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2  191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 3  12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...         NaN       NaN
# 4  702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 5  17/73 17/73 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขต...    ลาดพร้าว  ลาดพร้าว
# 6  627 ถนนสามเสน แขวง ดุสิต เขตดุสิต กรุงเทพมหานค...       ดุสิต     ดุสิต
# 7  110 ซอย มีสุข แขวง หนองบอน เขต ประเวศ กรุงเทพม...     หนองบอน    ประเวศ
# 8  208/22 ถ. พัฒนาการ แขวง ประเวศ เขต ประเวศ กรุง...      ประเวศ    ประเวศ
# 9  70 ซอย เฉลิมพระเกียรติ ร. 9 แขวง หนองบอน เขต ป...     หนองบอน    ประเวศ
#
#         province                      timestamp      state  star  \
# 0  กรุงเทพมหานคร  2021-09-03 12:51:09.453003+00  เสร็จสิ้น   NaN
# 1  กรุงเทพมหานคร  2021-09-19 14:56:08.924992+00  เสร็จสิ้น   4.0
# 2  กรุงเทพมหานคร  2021-09-26 05:03:52.594898+00  เสร็จสิ้น   NaN
# 3  กรุงเทพมหานคร  2021-10-14 10:45:27.713884+00  เสร็จสิ้น   NaN
# 4  กรุงเทพมหานคร  2021-12-09 12:29:08.408763+00  เสร็จสิ้น   5.0
# 5  กรุงเทพมหานคร  2021-12-13 05:53:36.861064+00  เสร็จสิ้น   NaN
# 6  กรุงเทพมหานคร  2021-12-17 08:46:02.610983+00  เสร็จสิ้น   5.0
# 7  กรุงเทพมหานคร  2021-12-18 14:50:52.437512+00  เสร็จสิ้น   2.0
# 8  กรุงเทพมหานคร  2021-12-21 23:03:58.450912+00  เสร็จสิ้น   2.0
# 9  กรุงเทพมหานคร  2021-12-22 10:15:33.294829+00  เสร็จสิ้น   5.0
#
#    count_reopen                  last_activity
# 0             0  2022-06-04 15:34:14.609206+00
# 1             0  2022-06-21 08:21:09.532782+00
# 2             0  2022-06-06 01:17:12.272904+00
# 3             0  2022-09-08 08:35:43.784519+00
# 4             0  2022-08-12 07:18:44.884945+00
# 5             0  2023-03-14 12:09:14.947437+00
# 6             0  2023-05-17 06:11:32.463984+00
# 7             0  2024-11-26 04:17:39.760344+00
# 8             0  2022-06-24 06:32:34.671236+00
# 9             0   2022-06-20 13:12:04.99444+00

# %% [markdown]
# # coordinate split
# จาก dataset คาดว่า latitude longitude สลับกัน

# %%
def split_coords(coords):
    if pd.isna(coords) or not isinstance(coords, str) or ',' not in coords:
        return pd.Series([np.nan, np.nan])
    lat, lon = coords.split(',', 1)
    try:
        return pd.Series([float(lon), float(lat)])
    except:
        return pd.Series([np.nan, np.nan])

df[['lat', 'lon']] = df['coords'].apply(split_coords)
 
# Remove invalid Thailand coordinates
df.loc[(df.lat < 5) | (df.lat > 21), ['lat']] = np.nan
df.loc[(df.lon < 97) | (df.lon > 106), ['lon']] = np.nan

df[['lat', 'lon']].head(20)
# Out:
#          lat        lon
# 0   13.81865  100.53084
# 1   13.67891  100.66709
# 2   13.72060  100.52649
# 3   13.81853  100.53099
# 4   13.82280  100.59165
# 5   13.80910  100.59131
# 6   13.77832  100.50848
# 7   13.67083  100.64690
# 8   13.72812  100.65617
# 9   13.68158  100.65440
# 10  13.68735  100.64844
# 11  13.71887  100.68837
# 12  13.70716  100.53764
# 13  13.70950  100.52674
# 14  13.70967  100.52678
# 15  13.70566  100.53025
# 16  13.68814  100.65816
# 17  13.70569  100.52970
# 18  13.70611  100.52789
# 19  13.70615  100.52760

# %% [markdown]
# ## Fill count_reopen Missing

# %%
df['count_reopen'] = df['count_reopen'].fillna(0).astype(int)
df['count_reopen'].value_counts().head()
# Out:
# count_reopen
# 0    734058
# 1     36607
# 2      8540
# 3      3268
# 4      1515
# Name: count, dtype: int64

# %% [markdown]
# ## Timestamp Cleaning

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')
df['last_activity'] = pd.to_datetime(df['last_activity'], errors='coerce')

# For missing last_activity, use timestamp
df['last_activity'] = df['last_activity'].fillna(df['timestamp'])

df[['timestamp','last_activity']].head()
# Out:
#                          timestamp                    last_activity
# 0 2021-09-03 12:51:09.453003+00:00 2022-06-04 15:34:14.609206+00:00
# 1 2021-09-19 14:56:08.924992+00:00 2022-06-21 08:21:09.532782+00:00
# 2 2021-09-26 05:03:52.594898+00:00 2022-06-06 01:17:12.272904+00:00
# 3 2021-10-14 10:45:27.713884+00:00 2022-09-08 08:35:43.784519+00:00
# 4 2021-12-09 12:29:08.408763+00:00 2022-08-12 07:18:44.884945+00:00

# %% [markdown]
# # column-by-column missing value

# %%
df['type'] = df['type'].fillna('Unknown')
# Fill using mode per type
df['organization'] = df.groupby('type')['organization'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else 'Unassigned'))
df['comment'] = df['comment'].fillna('')
df['has_photo'] = df['photo'].notna().astype(int)
df['has_photo_after'] = df['photo_after'].notna().astype(int)
df['district'] = df['district'].str.title().fillna('Unknown')
df['subdistrict'] = df['subdistrict'].str.title().fillna('Unknown')
df['star'] = df['star'].fillna(-1).astype(int)
df['last_activity'] = df['last_activity'].fillna(df['timestamp'])
df['state'] = df['state'].fillna('unknown')
df['count_reopen'] = df['count_reopen'].fillna(0).astype(int)

# %% [markdown]
# ## Feature Engineering
# เพิ่มหลังหัวข้อมา

# %% [markdown]
# # fix or remove impossible broken rows

# %%
print("Dataset shape before cleaning:", df.shape)
df = df.dropna(subset=['ticket_id', 'timestamp', 'lat', 'lon'])
df = df[df['province'].str.lower() == 'กรุงเทพมหานคร'].copy()
df = df[df['count_reopen'].fillna(0) >= 0]
df = df.dropna(how='all')
df = df.reset_index(drop=True)
print("Dataset shape after cleaning:", df.shape)
print("Sample rows:")
df.head(20)
# Out:
# Dataset shape before cleaning: (787026, 20)
# Dataset shape after cleaning: (651745, 20)
# Sample rows:
#       ticket_id                   type  \
# 0   2021-FYJTFP            {ความสะอาด}
# 1   2021-CGPMUN    {น้ำท่วม,ร้องเรียน}
# 2   2021-7XATFA                {สะพาน}
# 3   2021-9U2NJT              {น้ำท่วม}
# 4   2021-DVEWYM          {น้ำท่วม,ถนน}
# 5   2021-4D9Y98                Unknown
# 6   2021-7U9RED                Unknown
# 7   2021-8N9ZP8            {ความสะอาด}
# 8   2021-7K6QA3                Unknown
# 9   2021-8BTWZB          {ท่อระบายน้ำ}
# 10  2021-AKJBCU                Unknown
# 11  2021-EQWYWT            {ความสะอาด}
# 12  2022-7ZTKJV          {ถนน,ทางเท้า}
# 13  2022-E24G76                Unknown
# 14  2022-C37YCA                Unknown
# 15  2022-HB7Z8A  {ท่อระบายน้ำ,ทางเท้า}
# 16  2022-8EW3HK                Unknown
# 17  2022-8PL3NK            {ถนน,สะพาน}
# 18  2022-98YDNN                Unknown
# 19  2022-GNTHRA                {สะพาน}
#
#                                          organization  \
# 0                                          เขตบางซื่อ
# 1                        เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 2                                             เขตสาทร
# 3                      เขตบางซื่อ,ฝ่ายโยธา เขตบางซื่อ
# 4                    เขตลาดพร้าว,ฝ่ายโยธา เขตลาดพร้าว
# 5            เขตลาดพร้าว,การไฟฟ้านครหลวง เขตนวลจันทร์
# 6                                            เขตดุสิต
# 7   เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ,ฝ่ายรักษาความสะ...
# 8                      เขตประเวศ,ฝ่ายเทศกิจ เขตประเวศ
# 9                        เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 10                       เขตประเวศ,ฝ่ายโยธา เขตประเวศ
# 11  เขตประเวศ,สำนักสิ่งแวดล้อม กทม.,ฝ่ายสิ่งแวดล้อ...
# 12                           เขตสาทร,ฝ่ายโยธา เขตสาทร
# 13                         เขตสาทร,ฝ่ายเทศกิจ เขตสาทร
# 14                         เขตสาทร,ฝ่ายเทศกิจ เขตสาทร
# 15  เขตสาทร,สำนักการระบายน้ำ กทม.,ฝ่ายโยธา เขตสาทร...
# 16                    เขตประเวศ,สำนักสิ่งแวดล้อม กทม.
# 17  เขตสาทร,สำนักการจราจรและขนส่ง กรุงเทพมหานคร (ส...
# 18                                            เขตสาทร
# 19                         เขตสาทร,ฝ่ายเทศกิจ เขตสาทร
#
#                                               comment  \
# 0                                             ขยะเยอะ
# 1   น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
# 2     สะพานลอยปรับปรุงไม่เสร็จตามกำหนด\nปากซอย สาทร12
# 3                                             น้ำท่วม
# 4   ซอยลาดพร้าววังหิน 75 ถนนลาดพร้าววังหิน แขวงลาด...
# 5                         หน้าปากซอย ลาดพร้าววังหิน26
# 6   ยังไม่มีหน่วยงานไหนมาดูแลครับ รถจะเชี่ยวหลายคน...
# 7                   คนเอาขยะมาทิ้งจนกลายเป็นกองขยะค่ะ
# 8   ระยะหลังๆ นี้ พบเจอรถสิบล้อขนดิน ใส่ยางบังโคลน...
# 9   ขอแจ้งเรื่องท่อระบายน้ำบนถนนในซอยเสียหาย เป็นร...
# 10  แจ้งเรื่องพื้นผิวถนนเสียหาย มีการพยายามซ่อมแซม...
# 11     ปัญหากลิ่นขยะจากโรงขยะ 800 ตัน อ่อนนุช 86 ครับ
# 12  บริเวณนราธิวาส  แยกถนนจันทน์ ใกล้สวนสาธารณะช่อ...
# 13  มอเตอร์ไซด์จอดบนทางเท้าเป็นประจำ ฝั่งตรงข้ามตล...
# 14  มอเตอร์ไซด์จอดบนถนน ลดช่องจราจรทำให้การจราจรชะ...
# 15  ทางเท้าช่วง จันทน์ 18/5 สภาพโอเค แต่ฝาท่อเก่าแ...
# 16  อยากให้สวนหลวง ร9 และ สวนสาธารณะอื่นๆ ใน กทม เ...
# 17  ถนนจันทน์ช่วงสะพานสามถึงจันทน์ 18/5 น่าจะลาดยา...
# 18  ปากซอย จันทน์ 18/4 จักรยานยนต์นิยมขึ้นมาจอดบนท...
# 19  ริมถนน ตรงสะพานสามช่วงจันทน์ 18/6-18/4 ชอบมีรถ...
#
#                                                 photo  \
# 0   https://storage.googleapis.com/traffy_public_b...
# 1   https://storage.googleapis.com/traffy_public_b...
# 2   https://storage.googleapis.com/traffy_public_b...
# 3   https://storage.googleapis.com/traffy_public_b...
# 4   https://storage.googleapis.com/traffy_public_b...
# 5   https://storage.googleapis.com/traffy_public_b...
# 6   https://storage.googleapis.com/traffy_public_b...
# 7   https://storage.googleapis.com/traffy_public_b...
# 8   https://storage.googleapis.com/traffy_public_b...
# 9   https://storage.googleapis.com/traffy_public_b...
# 10  https://storage.googleapis.com/traffy_public_b...
# 11  https://storage.googleapis.com/traffy_public_b...
# 12  https://storage.googleapis.com/traffy_public_b...
# 13  https://storage.googleapis.com/traffy_public_b...
# 14  https://storage.googleapis.com/traffy_public_b...
# 15  https://storage.googleapis.com/traffy_public_b...
# 16  https://storage.googleapis.com/traffy_public_b...
# 17  https://storage.googleapis.com/traffy_public_b...
# 18  https://storage.googleapis.com/traffy_public_b...
# 19  https://storage.googleapis.com/traffy_public_b...
#
#                                           photo_after              coords  \
# 0                                                 NaN  100.53084,13.81865
# 1   https://storage.googleapis.com/traffy_public_b...  100.66709,13.67891
# 2                                                 NaN  100.52649,13.72060
# 3   https://storage.googleapis.com/traffy_public_b...  100.53099,13.81853
# 4                                                 NaN  100.59165,13.82280
# 5   https://storage.googleapis.com/traffy_public_b...  100.59131,13.80910
# 6   https://storage.googleapis.com/traffy_public_b...  100.50848,13.77832
# 7   https://storage.googleapis.com/traffy_public_b...  100.64690,13.67083
# 8   https://storage.googleapis.com/traffy_public_b...  100.65617,13.72812
# 9   https://storage.googleapis.com/traffy_public_b...  100.65440,13.68158
# 10  https://storage.googleapis.com/traffy_public_b...  100.64844,13.68735
# 11  https://storage.googleapis.com/traffy_public_b...  100.68837,13.71887
# 12  https://storage.googleapis.com/traffy_public_b...  100.53764,13.70716
# 13  https://storage.googleapis.com/traffy_public_b...  100.52674,13.70950
# 14                                                NaN  100.52678,13.70967
# 15                                                NaN  100.53025,13.70566
# 16  https://storage.googleapis.com/traffy_public_b...  100.65816,13.68814
# 17  https://storage.googleapis.com/traffy_public_b...  100.52970,13.70569
# 18  https://storage.googleapis.com/traffy_public_b...  100.52789,13.70611
# 19                                                NaN  100.52760,13.70615
#
#                                               address subdistrict  district  \
# 0   12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...     Unknown   Unknown
# 1   189 เฉลิมพระเกียรติ ร.9 แขวง หนองบอน เขต ประเว...     หนองบอน    ประเวศ
# 2   191/1 ถนน สาทรเหนือ แขวง สีลม เขตบางรัก กรุงเท...     ยานนาวา      สาทร
# 3   12/14 ถนน กรุงเทพ- นนทบุรี แขวง บางซื่อ เขตบาง...     Unknown   Unknown
# 4   702 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขตลาดพร้าว...    ลาดพร้าว  ลาดพร้าว
# 5   17/73 17/73 ถ. ลาดพร้าววังหิน แขวงลาดพร้าว เขต...    ลาดพร้าว  ลาดพร้าว
# 6   627 ถนนสามเสน แขวง ดุสิต เขตดุสิต กรุงเทพมหานค...       ดุสิต     ดุสิต
# 7   110 ซอย มีสุข แขวง หนองบอน เขต ประเวศ กรุงเทพม...     หนองบอน    ประเวศ
# 8   208/22 ถ. พัฒนาการ แขวง ประเวศ เขต ประเวศ กรุง...      ประเวศ    ประเวศ
# 9   70 ซอย เฉลิมพระเกียรติ ร. 9 แขวง หนองบอน เขต ป...     หนองบอน    ประเวศ
# 10  55 ถนน ศรีนครินทร์ แขวง หนองบอน เขต ประเวศ กรุ...     หนองบอน    ประเวศ
# 11  22/1 ซอย อ่อนนุช 86 แยก 2 แขวง ประเวศ เขต ประเ...      ประเวศ    ประเวศ
# 12  แยกจันทน์-นราธิวาส ถนน จันทน์ แขวง ทุ่งมหาเมฆ ...  ทุ่งมหาเมฆ      สาทร
# 13  184 ซอย จันทน์ 18/7 แขวง ทุ่งวัดดอน เขต สาทร ก...  ทุ่งวัดดอน      สาทร
# 14  184 ซอย จันทน์ 18/7 แขวง ทุ่งวัดดอน เขต สาทร ก...  ทุ่งวัดดอน      สาทร
# 15  1357/1-4 ซอย จันทน์ 23/2 แขวง ทุ่งวัดดอน เขต ส...  ทุ่งวัดดอน      สาทร
# 16  444 ซอย หมู่บ้านเสรี แขวง หนองบอน เขต ประเวศ ก...     หนองบอน    ประเวศ
# 17  1357/1-4 ซอย จันทน์ 23/2 แขวง ทุ่งวัดดอน เขต ส...  ทุ่งวัดดอน      สาทร
# 18  3 ซอย จันทน์ 18/4 แขวง ทุ่งวัดดอน เขต สาทร กรุ...  ทุ่งวัดดอน      สาทร
# 19  3 ซอย จันทน์ 18/4 แขวง ทุ่งวัดดอน เขต สาทร กรุ...  ทุ่งวัดดอน      สาทร
#
#          province                        timestamp           state  star  \
# 0   กรุงเทพมหานคร 2021-09-03 12:51:09.453003+00:00       เสร็จสิ้น    -1
# 1   กรุงเทพมหานคร 2021-09-19 14:56:08.924992+00:00       เสร็จสิ้น     4
# 2   กรุงเทพมหานคร 2021-09-26 05:03:52.594898+00:00       เสร็จสิ้น    -1
# 3   กรุงเทพมหานคร 2021-10-14 10:45:27.713884+00:00       เสร็จสิ้น    -1
# 4   กรุงเทพมหานคร 2021-12-09 12:29:08.408763+00:00       เสร็จสิ้น     5
# 5   กรุงเทพมหานคร 2021-12-13 05:53:36.861064+00:00       เสร็จสิ้น    -1
# 6   กรุงเทพมหานคร 2021-12-17 08:46:02.610983+00:00       เสร็จสิ้น     5
# 7   กรุงเทพมหานคร 2021-12-18 14:50:52.437512+00:00       เสร็จสิ้น     2
# 8   กรุงเทพมหานคร 2021-12-21 23:03:58.450912+00:00       เสร็จสิ้น     2
# 9   กรุงเทพมหานคร 2021-12-22 10:15:33.294829+00:00       เสร็จสิ้น     5
# 10  กรุงเทพมหานคร 2021-12-23 10:26:48.868250+00:00       เสร็จสิ้น    -1
# 11  กรุงเทพมหานคร 2021-12-28 03:59:06.003252+00:00       เสร็จสิ้น     4
# 12  กรุงเทพมหานคร 2022-01-02 10:53:25.580723+00:00       เสร็จสิ้น    -1
# 13  กรุงเทพมหานคร 2022-01-14 01:17:23.873811+00:00       เสร็จสิ้น    -1
# 14  กรุงเทพมหานคร 2022-01-14 01:18:57.194155+00:00       เสร็จสิ้น    -1
# 15  กรุงเทพมหานคร 2022-01-14 01:32:03.715912+00:00  กำลังดำเนินการ    -1
# 16  กรุงเทพมหานคร 2022-01-15 12:52:39.805944+00:00       เสร็จสิ้น    -1
# 17  กรุงเทพมหานคร 2022-01-16 10:57:39.184772+00:00       เสร็จสิ้น    -1
# 18  กรุงเทพมหานคร 2022-01-16 11:02:48.949248+00:00       เสร็จสิ้น    -1
# 19  กรุงเทพมหานคร 2022-01-16 11:08:54.141813+00:00       เสร็จสิ้น    -1
#
#     count_reopen                    last_activity       lat        lon  \
# 0              0 2022-06-04 15:34:14.609206+00:00  13.81865  100.53084
# 1              0 2022-06-21 08:21:09.532782+00:00  13.67891  100.66709
# 2              0 2022-06-06 01:17:12.272904+00:00  13.72060  100.52649
# 3              0 2022-09-08 08:35:43.784519+00:00  13.81853  100.53099
# 4              0 2022-08-12 07:18:44.884945+00:00  13.82280  100.59165
# 5              0 2023-03-14 12:09:14.947437+00:00  13.80910  100.59131
# 6              0 2023-05-17 06:11:32.463984+00:00  13.77832  100.50848
# 7              0 2024-11-26 04:17:39.760344+00:00  13.67083  100.64690
# 8              0 2022-06-24 06:32:34.671236+00:00  13.72812  100.65617
# 9              0 2022-06-20 13:12:04.994440+00:00  13.68158  100.65440
# 10             0 2022-09-28 08:35:36.703421+00:00  13.68735  100.64844
# 11             0 2022-07-12 06:50:02.315260+00:00  13.71887  100.68837
# 12             0 2022-06-08 05:46:12.776594+00:00  13.70716  100.53764
# 13             0 2022-06-22 08:06:08.170048+00:00  13.70950  100.52674
# 14             0 2022-06-22 08:10:20.715755+00:00  13.70967  100.52678
# 15             0 2022-09-15 15:51:15.433811+00:00  13.70566  100.53025
# 16             0 2022-06-20 07:12:17.332913+00:00  13.68814  100.65816
# 17             0 2023-08-18 06:52:20.549786+00:00  13.70569  100.52970
# 18             0 2022-06-09 03:49:13.904316+00:00  13.70611  100.52789
# 19             0 2022-06-23 08:06:52.928142+00:00  13.70615  100.52760
#
#     has_photo  has_photo_after
# 0           1                0
# 1           1                1
# 2           1                0
# 3           1                1
# 4           1                0
# 5           1                1
# 6           1                1
# 7           1                1
# 8           1                1
# 9           1                1
# 10          1                1
# 11          1                1
# 12          1                1
# 13          1                1
# 14          1                0
# 15          1                0
# 16          1                1
# 17          1                1
# 18          1                1
# 19          1                0

# %% [markdown]
# ## Save Cleaned Data

# %%
output_path = '../data_clean/bangkok_traffy_clean.csv'
import os
os.makedirs('../data_clean', exist_ok=True)
df.to_csv(output_path, index=False)
output_path
# Out:
# '../data_clean/bangkok_traffy_clean.csv'
